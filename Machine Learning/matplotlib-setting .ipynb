# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 그래프 그리기 위한 임의의 데이터 생성

# %%
import numpy as np

data = np.random.randint(-100,100,50).cumsum()
data
# Out:
# array([  88,  146,  180,  121,  108,  157,  166,  135,  132,  220,  282,
#         276,  352,  259,  182,  122,   69,   -3,    9,   30,   35,  -26,
#          69,   41,   46,  -44,  -18,   28,  -49, -120, -129, -216, -294,
#        -255, -237, -312, -231, -301, -354, -363, -331, -349, -322, -289,
#        -367, -363, -291, -319, -371, -352], dtype=int32)

# %%
plt.plot(range(50),data, 'r')
mpl.rcParams['axes.unicode_minus'] = False
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %% [markdown]
# ### 폰트 설정 전 설치되어있는 matplotlib의 버전과 위치 정보 가져옴

# %%
print('Version: ',mpl.__version__)
print('Download: ', mpl.__file__)
print('Setting: ', mpl.get_configdir())
print('Cache: ',mpl.get_cachedir())
# Out:
# Version:  3.2.2
# Download:  E:\20181526\anaconda3\lib\site-packages\matplotlib\__init__.py
# Setting:  C:\Users\예원\.matplotlib
# Cache:  C:\Users\예원\.matplotlib

# %%
print('Setting : ',mpl.matplotlib_fname())
# Out:
# Setting :  E:\20181526\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
f = [f.name for f in fm.fontManager.ttflist]
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumSquareRound', 'C:\\Windows\\Fonts\\NanumSquareRoundB.ttf'),
#  ('NanumSquare', 'C:\\WINDOWS\\Fonts\\NanumSquareL.ttf'),
#  ('NanumBarunpen', 'C:\\WINDOWS\\Fonts\\NanumBarunpenB.ttf'),
#  ('Nanum Pen Script', 'C:\\Windows\\Fonts\\NanumPen.ttf'),
#  ('NanumMyeongjo', 'C:\\WINDOWS\\Fonts\\NanumMyeongjo.ttf'),
#  ('NanumGothicCoding',
#   'C:\\Users\\예원\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothicCoding-Bold.ttf'),
#  ('NanumGothic', 'C:\\WINDOWS\\Fonts\\NanumGothicExtraBold.ttf'),
#  ('NanumBarunpen', 'C:\\WINDOWS\\Fonts\\NanumBarunpenR.ttf'),
#  ('NanumGothic', 'C:\\WINDOWS\\Fonts\\NanumGothicLight.ttf'),
#  ('NanumBarunGothic', 'C:\\Windows\\Fonts\\NanumBarunGothicLight.ttf'),
#  ('NanumBarunGothic', 'C:\\WINDOWS\\Fonts\\NanumBarunGothicBold.ttf'),
#  ('NanumGothic', 'C:\\Windows\\Fonts\\NanumGothicLight.ttf'),
#  ('NanumGothic', 'C:\\Windows\\Fonts\\NanumGothicBold.ttf'),
#  ('NanumSquare', 'C:\\WINDOWS\\Fonts\\NanumSquareR.ttf'),
# ...

# %% [markdown]
# ### Font를 사용하는 방법
#
# - FontProperties 사용 : 그래프의 폰트가 필요한 항목마다 지정을 해줘야 함
# - matplotlib.rcParams[]으로 전역 글꼴 설정 : 그래프에 설정해주면 폰트가 필요한 항목에 적용됨
# - 위의 방법을 mpl.matplotlib_fname()로 읽어지는 설정 파일에 직접 적어주는 법 : 모든 노트북에 적용됨

# %%
path = 'C:\\Windows\\Fonts\\NanumSquareRoundEB.ttf'
fontprop = fm.FontProperties(fname=path, size=18)

plt.plot(range(50),data, 'r')
plt.title('시간별 가격 추이',fontproperties=fontprop)
plt.ylabel('주식 가격',fontproperties=fontprop)
plt.xlabel('시간(분)',fontproperties=fontprop)
plt.show()

# %% [markdown]
# #### rcParams[]로 전역 글꼴 설정

# %%
plt.rcParams["font.family"] = 'NanumSquare'
plt.rcParams["font.size"] = 15
plt.rcParams["figure.figsize"] = (14,4)

# %%
plt.plot(range(50),data, 'r')
mpl.rcParams['axes.unicode_minus'] = False
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
plt.style.use('seaborn-pastel')
plt.show()

# %% [markdown]
# #### rcParams 대신 FontProperties와 plt.rc 사용하는 방법

# %%
path = 'C:\\WINDOWS\\Fonts\\NanumSquareRoundEB.ttf'
font_name = fm.FontProperties(fname=path, size=20).get_name()
print(font_name)
plt.rc('font', family=font_name)
mpl.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots()
ax.plot(data)
ax.set_title('시간별 가격 추이')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
plt.style.use('ggplot')
plt.show()
# Out:
# NanumSquareRound

# %% [markdown]
# ### rcParams를 설정파일에 직접 적어주는 방법

# %%
print('Settings : ',mpl.matplotlib_fname())
# Out:
# Settings :  E:\20181526\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
fig, ax = plt.subplots()
mpl.rcParams['axes.unicode_minus'] = False
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title('숫자 분포도')
plt.show()
