# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

df_train = pd.read_csv('datasets/titanic/train.csv')
df_test = pd.read_csv('datasets/titanic/test.csv')

# %% [markdown]
# ## 2. Exploratory data analysis

# %% [markdown]
# ### 2.1 Pclass, 사회경제적 지위

# %% [markdown]
# - Pclass는 ordinal 서수형 데이터, 카테고리이면서 순서가 있는 데이터 타입
# - Pclass에 따른 생존률의 차이를 알아봄 → groupby
# - Pclass & Survived 를 pclass로 묶어서 생존률을 알아봄

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'],as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %% [markdown]
# *pandas crosstab을 사용하면 위과정을 더 수월하게 할 수 있음*

# %%
pd.crosstab(df_train['Pclass'],
            df_train['Survived'],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_b307a90c_0973_11eb_b92a_409f389a2804row0_col0,#T_b307a90c_0973_11eb_b92a_409f389a2804row1_col1,#T_b307a90c_0973_11eb_b92a_409f389a2804row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_b307a90c_0973_11eb_b92a_409f389a2804row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_b307a90c_0973_11eb_b92a_409f389a2804row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_b307a90c_0973_11eb_b92a_409f389a2804row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_b307a90c_0973_11eb_b92a_409f389a2804row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_b307a90c_0973_11eb_b92a_409f389a2804row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_b307a90c_0973_11eb_b92a_409f389a2804row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_b307a90c_0973_11eb_b92a_409f389a2804row3_col0,#T_b307a90c_0973_11eb_b92a_409f389a2804row3_col1,#T_b307a90c_0973_11eb_b92a_409f389a2804row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b307a90c_0973_11eb_b92a_409f389a2804" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b307a90c_0973_11eb_b92a_409f389a2804level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_b307a90c_0973_11eb_b92a_409f389a2804level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_b307a90c_0973_11eb_b92a_409f389a2804level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_b307a90c_0973_11eb_b92a_409f389a2804level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_b307a90c_0973_11eb_b92a_409f389a2804row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
y_position = 1.02
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', y=y_position)
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()

# %% [markdown]
# ### 2.2 Sex, 성별

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %%
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_b392e04b_0973_11eb_8034_409f389a2804row0_col0,#T_b392e04b_0973_11eb_8034_409f389a2804row0_col2,#T_b392e04b_0973_11eb_8034_409f389a2804row1_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_b392e04b_0973_11eb_8034_409f389a2804row0_col1{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_b392e04b_0973_11eb_8034_409f389a2804row1_col0{
#             background-color:  #2c9666;
#             color:  #000000;
#         }#T_b392e04b_0973_11eb_8034_409f389a2804row1_col2{
#             background-color:  #8bc566;
#             color:  #000000;
#         }#T_b392e04b_0973_11eb_8034_409f389a2804row2_col0,#T_b392e04b_0973_11eb_8034_409f389a2804row2_col1,#T_b392e04b_0973_11eb_8034_409f389a2804row2_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_b392e04b_0973_11eb_8034_409f389a2804" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b392e04b_0973_11eb_8034_409f389a2804level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_b392e04b_0973_11eb_8034_409f389a2804row0_col0" class="data row0 col0" >81</td>
#                         <td id="T_b392e04b_0973_11eb_8034_409f389a2804row0_col1" class="data row0 col1" >233</td>
#                         <td id="T_b392e04b_0973_11eb_8034_409f389a2804row0_col2" class="data row0 col2" >314</td>
#             </tr>
#             <tr>
#                         <th id="T_b392e04b_0973_11eb_8034_409f389a2804level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_b392e04b_0973_11eb_8034_409f389a2804row1_col0" class="data row1 col0" >468</td>
#                         <td id="T_b392e04b_0973_11eb_8034_409f389a2804row1_col1" class="data row1 col1" >109</td>
#                         <td id="T_b392e04b_0973_11eb_8034_409f389a2804row1_col2" class="data row1 col2" >577</td>
#             </tr>
#             <tr>
#                         <th id="T_b392e04b_0973_11eb_8034_409f389a2804level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_b392e04b_0973_11eb_8034_409f389a2804row2_col0" class="data row2 col0" >549</td>
#                         <td id="T_b392e04b_0973_11eb_8034_409f389a2804row2_col1" class="data row2 col1" >342</td>
#                         <td id="T_b392e04b_0973_11eb_8034_409f389a2804row2_col2" class="data row2 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 2.3 Both Sex and Pclass

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train,size=6, aspect=1.5)

# %% [markdown]
# *hue 대신 column을 이용하면 아래와 같은 그래프가 그려짐*

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass',
              data=df_train, satureation=.5,
               size=9, aspect=1
              )

# %% [markdown]
# ### 2.4 Age, 나이

# %%
print('제일 나이 많은 탑승객 : {:.1f} Years'.format(df_train['Age'].max()))
print('제일 어린 탑승객 : {:.1f} Years'.format(df_train['Age'].min()))
print('탑승객 평균 나이 : {:.1f} Years'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객 : 80.0 Years
# 제일 어린 탑승객 : 0.4 Years
# 탑승객 평균 나이 : 29.7 Years

# %% [markdown]
# *생존자에 따른 histogram*

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# %%
# Age distribution withing classes
plt.figure(figsize=(8, 6))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %% [markdown]
# - *class가 높을 수록 나이 많은 사람의 비중이 커짐*
# - *나이대를 변화시키면서 생존률을 확인*
# - *나이 범위를 점점 넓혀가며, 생존률을 확인*

# %%
cummulate_survival_ratio = []
for i in range(1, 80):
    cummulate_survival_ratio.append(df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived']))
    
plt.figure(figsize=(7, 7))
plt.plot(cummulate_survival_ratio)
plt.title('Survival rate change depending on range of Age', y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0~x)')
plt.show()

# %% [markdown]
# ### 2.5 Pclass, Sex, Age
# x 축은 우리가 나눠서 보고싶어하는 case(여기선 Pclass, Sex) 를 나타내고, y 축은 보고 싶어하는 distribution(Age)

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=df_train, scale='count', split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=df_train, scale='count', split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()
